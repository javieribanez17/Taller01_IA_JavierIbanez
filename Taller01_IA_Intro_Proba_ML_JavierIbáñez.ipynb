# %% [markdown]
# <a href="https://colab.research.google.com/github/javieribanez17/Taller01_IA_JavierIbanez/blob/main/Taller01_IA_Intro_Proba_ML_JavierIb%C3%A1%C3%B1ez.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Taller en clase 1**
# Generando numeros aleatorios en ptython.
# Objetivos:
# 1. Familiarizar al estudiante con la generación de numeros aleatorios de diferentes distribuciones en python.
# 2. Usar las herramientas de python de manejo de arreglos.
# 3. Usar las herramientas de generación de gráficas de python.
# ## Entrega
# En U-virtual, antes de la siguiente clase en el link designado como Taller en clase 1.

# %%
import numpy  #as np# si no lo tiene instalado por favor correr en su consola         $pip install numpy
import scipy #as sp# si no lo tiene instalado por favor correr en su consola         $pip install scipy
import matplotlib #si no lo tiene instalado por favor correr  en su consola   $pip install matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# # **Primer punto de distribuciones discretas.**
# 1. Cree un arreglo de N muestras con N a su selección, pero mayor a 1000, de números distribuidos con las correspondientes distribuciones, para cada arreglo de números:
# 1. Grafique los números aleatorios,
# 2. Ordene de menor a mayor y grafique,
# 4. Encuentre los valores teoricos de media y varianza, y comparelos con los estimados.

# %% [markdown]
# # Distribución discreta de Bernoulli
# ---

# %%
#Para todas las simulaciones:
N=100000
m=100
numpy.random.seed(seed=2**32 - 1)#Para fijar una semilla para los experimentos y que los numeros generados siempre sean los mismos en cada corrida completa de este fuente.

# %%
# Bernoulli con cierto p entre 0 y 1
p=0.3
from scipy.stats import bernoulli
mean, var, skew, kurt = bernoulli.stats(p, moments='mvsk')
r = bernoulli.rvs(p, size=N)
#ver https://docs.scipy.org/doc/scipy-0.14.0/reference/stats.html
plt.plot(r)
plt.title(str(N)+" puntos distribuidos bernoulli con p="+str(p))
plt.show()

# %%
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos distribuidos bernoulli ordenados con p="+str(p))
plt.show()

# %%
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos bernoulli con p="+str(p))
plt.show()
print("Note que hasta ahora no sabemos el tipo de nuestro arreglo r:")
print(type(r))
print("Vamos a hallar algunas estimaciones de estadisticas de r")
# ver https://numpy.org/doc/stable/reference/routines.statistics.html 
avg=r.mean()
varest=r.var()
print("Los valores teoricos de la media y varianza para la bernoulli con p=",p,"son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza para la bernoulli con p=",p,"son u_est=" ,avg,"var_est=",varest)
# Out:
# Note que hasta ahora no sabemos el tipo de nuestro arreglo r:
# <class 'numpy.ndarray'>
# Vamos a hallar algunas estimaciones de estadisticas de r
# Los valores teoricos de la media y varianza para la bernoulli con p= 0.3 son u= 0.3 var= 0.21
# Los valores estimados en nuestro experimento de la media y varianza para la bernoulli con p= 0.3 son u_est= 0.29788 var_est= 0.20914750560000003

# %% [markdown]
# # Distribución discreta binomial
# ---

# %%
# binomial con cierto p entre 0 y 1
n=10
p=0.5
from scipy.stats import binom
mean, var, skew, kurt = binom.stats(n,p, moments='mvsk')
r = binom.rvs(n,p, size=N)
plt.plot(r)
plt.title(str(N)+" puntos distribuidos binomial con p="+str(p))
plt.show()

# %%
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos distribuidos bernoulli ordenados con p="+str(p))
plt.show()

# %%
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos binomial con p="+str(p))
plt.show()
print("r es de tipo " + str(type(r)))
avg=r.mean()
varest=r.var()
print("Los valores teoricos de la media y varianza para la binomial con p=",p,"son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza para la binomial con p=",p,"son u_est=" ,avg,"var_est=",varest)
# Out:
# r es de tipo <class 'numpy.ndarray'>
# Los valores teoricos de la media y varianza para la binomial con p= 0.5 son u= 5.0 var= 2.5
# Los valores estimados en nuestro experimento de la media y varianza para la binomial con p= 0.5 son u_est= 4.99695 var_est= 2.4928206975000005

# %% [markdown]
# # Distribución discreta geométrica
# ---

# %%
# Geometrica con cierto p entre 0 y 1
p=0.3
from scipy.stats import geom
mean, var, skew, kurt = geom.stats(p, moments='mvsk')
r = geom.rvs(p, size=N)
plt.plot(r)
plt.title(str(N)+" puntos distribuidos geométricos con p="+str(p))
plt.show()

# %%
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos distribuidos geometricamente ordenados con p="+str(p))
plt.show()

# %%
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos geometricamente con p="+str(p))
plt.show()
print("r es de tipo " + str(type(r)))
avg=r.mean()
varest=r.var()
print("Los valores teoricos de la media y varianza para la D.Geométrica con p=",p,"son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza para la D.Geométrica con p=",p,"son u_est=" ,avg,"var_est=",varest)
# Out:
# r es de tipo <class 'numpy.ndarray'>
# Los valores teoricos de la media y varianza para la D.Geométrica con p= 0.3 son u= 3.3333333333333335 var= 7.777777777777779
# Los valores estimados en nuestro experimento de la media y varianza para la D.Geométrica con p= 0.3 son u_est= 3.32724 var_est= 7.7704139824

# %% [markdown]
# # Distribución discreta de Poisson
# ---

# %%
# D.Poisson con cierto lamnda L
L=5 
from scipy.stats import poisson
mean, var, skew, kurt = poisson.stats(L, moments='mvsk')
r = poisson.rvs(L, size=N)
plt.plot(r)
plt.title(str(N)+" puntos distribuidos bernoulli con p="+str(L))
plt.show()

# %%
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos con distribución de Poisson ordenados con Lamnda L="+str(L))
plt.show()

# %%
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos con distribución de Poisson con L="+str(L))
plt.show()
print("r es de tipo " + str(type(r)))
avg=r.mean()
varest=r.var()
print("Los valores teoricos de la media y varianza para la D. Poisson con L=",L,"son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza para la  D. Poisson con L=",L,"son u_est=" ,avg,"var_est=",varest)
# Out:
# r es de tipo <class 'numpy.ndarray'>
# Los valores teoricos de la media y varianza para la D. Poisson con L= 5 son u= 5.0 var= 5.0
# Los valores estimados en nuestro experimento de la media y varianza para la  D. Poisson con L= 5 son u_est= 4.99396 var_est= 4.9762235184

# %% [markdown]
# # Distribución discreta binomial negativa
# ---

# %%
# binomial negativa con cierto p entre 0 y 1
n=5 # fallos=aciertos por p=0.5
p=0.5
from scipy.stats import nbinom
mean, var, skew, kurt = nbinom.stats(n,p, moments='mvsk')
r = nbinom.rvs(n,p, size=N)
plt.plot(r)
plt.title(str(N)+" puntos distribuidos bernoulli con p="+str(p))
plt.show()

# %%
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos con distribución binomial negativa ordenados con p="+str(p))
plt.show()

# %%
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos con distribución binomial negativa con p="+str(p))
plt.show()
print("r es de tipo " + str(type(r)))
avg=r.mean()
varest=r.var()
print("Los valores teoricos de la media y varianza para la D. Binomial negativa con p=",p,"son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza para la  D. Binomial negativa con p=",p,"son u_est=" ,avg,"var_est=",varest)
# Out:
# r es de tipo <class 'numpy.ndarray'>
# Los valores teoricos de la media y varianza para la D. Binomial negativa con p= 0.5 son u= 5.0 var= 10.0
# Los valores estimados en nuestro experimento de la media y varianza para la  D. Binomial negativa con p= 0.5 son u_est= 4.99199 var_est= 9.975825839899999

# %% [markdown]
# # **Segundo punto de distribuciones continuas.**

# %% [markdown]
# # Distribución continua normal
# ---

# %%
#Para todas las simulaciones:
N=100000
m=300
numpy.random.seed(seed=1314926535)#Para fijar una semilla para los experimentos y que los numeros generados siempre sean los mismos en cada corrida completa de este fuente.

# %%
# Normal de media 5 y desviación estandar 0.5
u=5
std=0.5
mean, var, skew, kurt = scipy.stats.norm.stats(moments='mvsk',loc=u,scale=std)
r = scipy.stats.norm.rvs (loc=u,scale=std, size=N)
#ver https://docs.scipy.org/doc/scipy-0.14.0/reference/stats.html
plt.plot(r)
plt.title(str(N)+" puntos distribuidos normales con media="+str(u)+" y std="+str(std))
plt.show()
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos distribuidos normales ordenados con u="+str(u))
plt.show()
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos normales con u="+str(u)+ " y std= "+str(std))
plt.show()
print("Note que hasta ahora no sabemos el tipo de nuestro arreglo r:")
print(type(r))
print("Vamos a hallar algunas estimaciones de estadisticas de r")
# ver https://numpy.org/doc/stable/reference/routines.statistics.html 
avg=r.mean()
varest=r.var()
print("Los valores teoricos de la media y varianza para la normal son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza son u_est=" ,avg,"var_est=",varest)
# Out:
# Note que hasta ahora no sabemos el tipo de nuestro arreglo r:
# <class 'numpy.ndarray'>
# Vamos a hallar algunas estimaciones de estadisticas de r
# Los valores teoricos de la media y varianza para la normal son u= 5.0 var= 0.25
# Los valores estimados en nuestro experimento de la media y varianza son u_est= 4.998901381233632 var_est= 0.2466774046428929

# %% [markdown]
# # Distribución continua uniforme
# ---

# %%
# D. Uniforme entre 0 y 255
a=0
b=255
from scipy.stats import uniform
mean, var, skew, kurt = uniform.stats(moments='mvsk',loc=a,scale=b)
r = uniform.rvs (loc=a,scale=b, size=N)
plt.plot(r)
plt.title(str(N)+" puntos distribuidos uniformemente")
plt.show()
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos distribuidos uniformemente")
plt.show()
plt.hist(r, bins = m)
plt.title("Histograma de los puntos distribuidos uniformemente")
plt.show()
print("r es de tipo " + str(type(r)))
avg=r.mean()
varest=r.var()
print("Los valores teoricos de la media y varianza para la normal son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza son u_est=" ,avg,"var_est=",varest)
# Out:
# r es de tipo <class 'numpy.ndarray'>
# Los valores teoricos de la media y varianza para la normal son u= 127.5 var= 5418.75
# Los valores estimados en nuestro experimento de la media y varianza son u_est= 127.73372178414431 var_est= 5413.755788853737

# %% [markdown]
# # Distribución continua exponencial
# ---

# %%
# D. Exponencial con lamnda L
L=0.3
from scipy.stats import expon
mean, var, skew, kurt = expon.stats(L,moments='mvsk')
r = expon.rvs (L,size=N)
plt.plot(r)
plt.title(str(N)+" puntos con D. Exponencial con lamnda="+str(L))
plt.show()
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos con D. Exponencial con lamnda="+str(L))
plt.show()
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos con D. Exponencial con lamnda="+str(L))
plt.show()
print("r es de tipo " + str(type(r))) 
avg=r.mean()
varest=r.var()
print("Los valores teoricos de la media y varianza para la normal son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza son u_est=" ,avg,"var_est=",varest)
# Out:
# r es de tipo <class 'numpy.ndarray'>
# Los valores teoricos de la media y varianza para la normal son u= 1.3 var= 1.0
# Los valores estimados en nuestro experimento de la media y varianza son u_est= 1.2999539382188863 var_est= 1.0080227368385684

# %% [markdown]
# # Distribución continua Chi cuadrada
# ---

# %%
# D. Chi cuadrada con K grados de libertad
K=3.0
from scipy.stats import chi2
mean, var, skew, kurt = chi2.stats(K,moments='mvsk')
r = chi2.rvs (K,size=N)
plt.plot(r)
plt.title(str(N)+" puntos con D. Chi cuadrada con grados de libertad="+str(K))
plt.show()
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos con D. Chi cuadrada con grados de libertad="+str(K))
plt.show()
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos con D. Chi cuadrada con grados de libertad="+str(K))
plt.show()
print("r es de tipo " + str(type(r)))
avg=r.mean()
varest=r.var()
print("Los valores teoricos de la media y varianza para la normal son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza son u_est=" ,avg,"var_est=",varest)
# Out:
# r es de tipo <class 'numpy.ndarray'>
# Los valores teoricos de la media y varianza para la normal son u= 3.0 var= 6.0
# Los valores estimados en nuestro experimento de la media y varianza son u_est= 2.9947012558927835 var_est= 5.965658639159293

# %% [markdown]
# # Distribución continua Gamma
# ---

# %%
# D. Gamma con parámetros k y theta t
k=2.54
t=0.43
from scipy.stats import gamma
mean, var, skew, kurt = gamma.stats(a=k,scale=t,moments='mvsk')
r = gamma.rvs (a=k,scale=t,size=N)
plt.plot(r)
plt.title(str(N)+" puntos distribuidos con D. Gamma con k="+str(k)+" y theta="+str(t))
plt.show()
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos distribuidos con D. Gamma con k="+str(k)+" y theta="+str(t))
plt.show()
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos con D. Gamma con k="+str(k)+" y theta="+str(t))
plt.show()
print("r es de tipo " + str(type(r)))
avg=r.mean()
varest=r.var()
print("Los valores teoricos de la media y varianza para la normal son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza son u_est=" ,avg,"var_est=",varest)
# Out:
# r es de tipo <class 'numpy.ndarray'>
# Los valores teoricos de la media y varianza para la normal son u= 1.0922 var= 0.469646
# Los valores estimados en nuestro experimento de la media y varianza son u_est= 1.0943710087686467 var_est= 0.46886019302932097
